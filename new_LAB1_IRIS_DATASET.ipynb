# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\\Users\\shrikant\\Desktop\\content\\SEM2\Machine Learning\\LAB\\irisdata.csv")
data
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %%
data.interpolate()
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4        0.200000
# 1                4.9             3.0              1.4        0.200000
# 2                4.7             3.2              1.3        0.200000
# 3                4.6             3.1              1.5        0.200000
# 4                5.0             3.6              1.4        0.200000
# 5                5.4             3.9              1.7        0.400000
# 6                4.6             3.4              1.4        0.300000
# 7                5.0             3.4              1.5        0.266667
# 8                4.4             2.9              1.4        0.233333
# 9                4.9             3.1              1.5        0.200000
# 10               5.4             3.7              1.5        0.166667
# 11               4.8             3.4              1.6        0.133333
# ...

# %%
x = data['sepal_length_cm']
y = data['petal_length_cm']

# %%
plt.style.use('classic')
fig, ax = plt.subplots(figsize=(8, 3))
ax.scatter(x, y, alpha=0.5, color='orchid')
ax.set_title('Example Scatter Plot')
ax.grid(True)
fig.tight_layout(pad=1)
fig.savefig('C://Users//shrikant//Desktop//content//SEM2//Machine Learning//LAB//LAB1//filename1.png', dpi=125)

# %%
before = x
after = y
fig, ax = plt.subplots(figsize=(8, 5))
width = 0.4 # bar width
xlocs = np.arange(len(before))
ax.bar(xlocs-width, before, width,
color='cornflowerblue', label='sepal_length_cm')
ax.bar(xlocs, after, width,
color='hotpink', label='petal_length_cm')
# --- labels, grids and title, then save
ax.set_xticks(ticks=range(len(before)))
ax.set_xticklabels(labels)
ax.yaxis.grid(True)
ax.legend(loc='best')
fig.tight_layout(pad=1)
fig.savefig('C://Users//shrikant//Desktop//content//SEM2//Machine Learning//LAB//LAB1//filename2.png', dpi=125)
