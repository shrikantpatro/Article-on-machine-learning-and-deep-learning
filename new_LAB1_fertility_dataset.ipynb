# %%
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd
import numpy as np

# %%
desired_width=320
pd.set_option('display.width', desired_width)
#np.set_printoption(linewidth=desired_width)
pd.set_option('display.max_columns',20)

# %%
data = pd.read_csv("C:\\Users\\shrikant\\Desktop\\content\\SEM2\Machine Learning\\LAB\\Dataset\\Blood Transfusion Service Center.csv")
data = pd.read_csv("C:\\Users\\shrikant\\Desktop\\content\\SEM2\Machine Learning\\LAB\\Dataset\\Blood Transfusion Service Center.csv", na_values=['NA'])

# %%
print(data.head)
# Out:
# <bound method NDFrame.head of      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                   2                 50                  12500             98        1
# 1                   0                 13                   3250             28        1
# 2                   1                 16                   4000             35        1
# 3                   2                 20                   5000             45        1
# 4                   1                 24                   6000             77        0
# 5                   4                  4                   1000              4        0
# 6                   2                  7                   1750             14        1
# 7                   1                 12                   3000             35        0
# 8                   2                  9                   2250             22        1
# ...

# %%
data = pd.read_csv("C:\\Users\\shrikant\\Desktop\\content\\SEM2\Machine Learning\\LAB\\Dataset\\Blood Transfusion Service Center.csv", na_values=['xxx'])
print(data.head())
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                 2                 50                  12500             98        1
# 1                 0                 13                   3250             28        1
# 2                 1                 16                   4000             35        1
# 3                 2                 20                   5000             45        1
# 4                 1                 24                   6000             77        0

# %%
data.describe()
# Out:
#        Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)     donated
# count        748.000000         748.000000             748.000000     748.000000  748.000000
# mean           9.506684           5.514706            1378.676471      34.282086    0.237968
# std            8.095396           5.839307            1459.826781      24.376714    0.426124
# min            0.000000           1.000000             250.000000       2.000000    0.000000
# 25%            2.750000           2.000000             500.000000      16.000000    0.000000
# 50%            7.000000           4.000000            1000.000000      28.000000    0.000000
# 75%           14.000000           7.000000            1750.000000      50.000000    0.000000
# max           74.000000          50.000000           12500.000000      98.000000    1.000000

# %%
data.loc[data['donated'] == 1,'donated'] = 11
data.loc[data['donated'] == 0,'donated'] = 10
print(data.head())
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                 2                 50                  12500             98       11
# 1                 0                 13                   3250             28       11
# 2                 1                 16                   4000             35       11
# 3                 2                 20                   5000             45       11
# 4                 1                 24                   6000             77       10

# %%
print(data['donated'].unique())
print(data['Time (months)'].unique())
data1 = data.loc[(data['donated'] !=10) & (data['Monetary (c.c. blood)'] >= 10000)]
print(data1)
# Out:
# [11 10]
# [98 28 35 45 77  4 14 22 58 47 15 11 48 49 16 40 34 21 26 64 57 53 69 36
#   2 46 52 81 29  9 74 25 51 71 23 86 38 76 70 59 82 61 79 41 33 10 95 88
#  19 37 39 78 42 27 24 63 43 75 73 50 60 17 72 62 30 31 65 89 87 93 83 32
#  12 18 55  3 13 54]
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                   2                 50                  12500             98       11
# 9                   5                 46                  11500             98       11
# 500                 2                 43                  10750             86       11
# 505                 2                 41                  10250             98       11

# %%
data.loc[(data['donated'] !=10) & (data['Monetary (c.c. blood)'] >= 10000)].hist()
plt.show()

# %%
data2 = data.loc[(data['Monetary (c.c. blood)'] >= 10000)]
print(data2)
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                   2                 50                  12500             98       11
# 9                   5                 46                  11500             98       11
# 500                 2                 43                  10750             86       11
# 503                 2                 44                  11000             98       10
# 505                 2                 41                  10250             98       11

# %%
data3 = data.loc[(data['Monetary (c.c. blood)'] >= 10000)]
print(data3)
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                   2                 50                  12500             98       11
# 9                   5                 46                  11500             98       11
# 500                 2                 43                  10750             86       11
# 503                 2                 44                  11000             98       10
# 505                 2                 41                  10250             98       11

# %%
data.loc[(data['Recency (months)'].isnull()) |(data['Frequency (times)'].isnull()) |(data['Monetary (c.c. blood)'].isnull()) |(data['Time (months)'].isnull())| (data['donated'].isnull())]
print(data.head())
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                 2                 50                  12500             98       11
# 1                 0                 13                   3250             28       11
# 2                 1                 16                   4000             35       11
# 3                 2                 20                   5000             45       11
# 4                 1                 24                   6000             77       10

# %%
data.loc[(data['donated'] == 11,'Time (months)')]
print(data.head())
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0                 2                 50                  12500             98       11
# 1                 0                 13                   3250             28       11
# 2                 1                 16                   4000             35       11
# 3                 2                 20                   5000             45       11
# 4                 1                 24                   6000             77       10

# %%
average_petal_width=data.loc[(data['Time (months)']<=100 ,'Time (months)')].mean()
print(average_petal_width)
# Out:
# 34.282085561497325

# %%
data.loc[(data['donated']==11) & (data['Recency (months)'].isnull()),'Recency (months)']=average_petal_width
print(data['Recency (months)'])
sb.pairplot(data,hue='donated')
# Out:
# 0       2.0
# 1       0.0
# 2       1.0
# 3       2.0
# 4       1.0
# 5       4.0
# 6       2.0
# 7       1.0
# 8       2.0
# 9       5.0
# 10      4.0
# 11      0.0
# 12      2.0
# 13      1.0
# 14      2.0
# 15      2.0
# 16      2.0
# 17      2.0
# 18      2.0
# 19      2.0
# 20      2.0
# 21      4.0
# 22      2.0
# 23      2.0
# 24      9.0
# 25      4.0
# 26      4.0
# 27      4.0
# 28      4.0
# 29      4.0
#        ...
# 718    21.0
# 719    23.0
# 720    21.0
# 721    23.0
# 722    21.0
# 723    23.0
# 724    21.0
# 725    21.0
# 726    25.0
# 727    21.0
# 728    21.0
# 729    23.0
# 730    21.0
# 731    14.0
# 732    23.0
# 733    23.0
# 734    23.0
# 735    23.0
# 736    23.0
# 737    23.0
# 738    23.0
# 739    23.0
# 740    23.0
# 741    23.0
# 742    16.0
# 743    23.0
# 744    21.0
# 745    23.0
# 746    39.0
# 747    72.0
# Name: Recency (months), Length: 748, dtype: float64
# ---------------------------------------------------------------------------
# ...

# %%
print(data.mean())
print(data.median())
print(data.mode())
plt.figure(figsize=(10, 10))
# Out:
# Recency (months)            9.506684
# Frequency (times)           5.514706
# Monetary (c.c. blood)    1378.676471
# Time (months)              34.282086
# donated                    10.237968
# dtype: float64
# Recency (months)            7.0
# Frequency (times)           4.0
# Monetary (c.c. blood)    1000.0
# Time (months)              28.0
# donated                    10.0
# dtype: float64
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  donated
# 0               2.0                  1                    250              4       10

# %%
for column_index, column in enumerate(data2.columns):
   if column == 'donated':
      continue
   plt.subplot(2, 2, column_index + 1)
   sb.violinplot(x='donated', y=column, data=data2)
# Out:
# C:\Users\shrikant\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
for column_index, column in enumerate(data3.columns):
   if column == 'donated':
      continue
   plt.subplot(2, 2, column_index + 1)
   sb.boxplot(x='donated', y=column, data=data3)

print("Done")
plt.show()
# Out:
# Done
